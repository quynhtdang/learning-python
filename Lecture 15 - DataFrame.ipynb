# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
#numpy and pandas are packages
#Series, DataFrame, webbrowser are libraries

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
#using "pandas", copy and read data from the clipboard (the content copied from the link above)
#dataframe is like an Excel spreadsheet
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/io/clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
nfl_frame.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL Season',
#        'Division'],
#       dtype='object')

# %%
#grab the content of a specific column. the output is a series
#dataframename.columnname
nfl_frame.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_frame['First NFL Season']
#output is a series
# Out:
# 0    1960
# 1    1921
# 2    1920
# 3    1966
# 4    1960
# Name: First NFL Season, dtype: int64

# %%
#create a dataframe
DataFrame(nfl_frame,columns=['Team','First NFL Season','GP'])
# Out:
#                       Team  First NFL Season     GP
# 0           Dallas Cowboys              1960    882
# 1        Green Bay Packers              1921  1,336
# 2            Chicago Bears              1920  1,370
# 3           Miami Dolphins              1966    800
# 4  New England Patriots[b]              1960    884

# %%
#ask for a column that doesn't exsist -> pandas will fill the nonexistent column with Null values
DataFrame(nfl_frame,columns=['Team','First NFL Season','GP','Stadium'])
# Out:
#                       Team  First NFL Season     GP  Stadium
# 0           Dallas Cowboys              1960    882      NaN
# 1        Green Bay Packers              1921  1,336      NaN
# 2            Chicago Bears              1920  1,370      NaN
# 3           Miami Dolphins              1966    800      NaN
# 4  New England Patriots[b]              1960    884      NaN

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
#retrieve the first few rows of a dataframe
#first 3 rows
nfl_frame.head(3)
# Out:
#    Rank               Team     GP  Won  Lost  Tied   Pct.  First NFL Season  \
# 0     1     Dallas Cowboys    882  502   374     6  0.573              1960
# 1     2  Green Bay Packers  1,336  737   562    37  0.565              1921
# 2     3      Chicago Bears  1,370  749   579    42  0.562              1920
#
#     Division
# 0   NFC East
# 1  NFC North
# 2  NFC North

# %%
#retrieve the few end rows of a dataframe
#last 2 rows
nfl_frame.tail(2)
# Out:
#    Rank                     Team   GP  Won  Lost  Tied   Pct.  \
# 3     4           Miami Dolphins  800  445   351     4  0.559
# 4     5  New England Patriots[b]  884  489   386     9  0.558
#
#    First NFL Season  Division
# 3              1966  AFC East
# 4              1960  AFC East

# %%
#grab all rows
nfl_frame.tail()
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
#retrieve rows on a particular index
#grab 4th row (index 3)
nfl_frame.ix[3]
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   This is separate from the ipykernel package so we can avoid doing imports until
# Rank                             4
# Team                Miami Dolphins
# GP                             800
# Won                            445
# Lost                           351
# Tied                             4
# Pct.                         0.559
# First NFL Season              1966
# Division                  AFC East
# Name: 3, dtype: object

# %%
#assign values to an entire column
nfl_frame['Stadium'] = "Levi's Stadium"
#levi's has a single quote, so name of value has to be wrapped inside double quotes

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East  Levi's Stadium
# 1              1921  NFC North  Levi's Stadium
# 2              1920  NFC North  Levi's Stadium
# 3              1966   AFC East  Levi's Stadium
# 4              1960   AFC East  Levi's Stadium

# %%
#pass a list of 5 values to a column
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division  Stadium
# 0              1960   NFC East        0
# 1              1921  NFC North        1
# 2              1920  NFC North        2
# 3              1966   AFC East        3
# 4              1960   AFC East        4

# %%
#add a series to a dataframe
#make a new object called "stadiums"
#assign indexes to 2 values in the series
stadiums = Series(["Levi's Satidum", "AT&T Stadium"],index=[4,0])
stadiums
# Out:
# 4    Levi's Satidum
# 0      AT&T Stadium
# dtype: object

# %%
#add a series to dataframe. call the column of the data frame to which you want to add the values of the series 'stadiums'
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division         Stadium
# 0              1960   NFC East    AT&T Stadium
# 1              1921  NFC North             NaN
# 2              1920  NFC North             NaN
# 3              1966   AFC East             NaN
# 4              1960   AFC East  Levi's Satidum

# %%
#delete an entire column from a dataframe
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank                     Team     GP  Won  Lost  Tied   Pct.  \
# 0     1           Dallas Cowboys    882  502   374     6  0.573
# 1     2        Green Bay Packers  1,336  737   562    37  0.565
# 2     3            Chicago Bears  1,370  749   579    42  0.562
# 3     4           Miami Dolphins    800  445   351     4  0.559
# 4     5  New England Patriots[b]    884  489   386     9  0.558
#
#    First NFL Season   Division
# 0              1960   NFC East
# 1              1921  NFC North
# 2              1920  NFC North
# 3              1966   AFC East
# 4              1960   AFC East

# %%
#construct a data frame by passing in a dictionary
#create a dictionar,y called 'data'
data = {'City':['SF','LA','NYC'],'Population':[837000,3380000,8400000]}
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3380000, 8400000]}

# %%
#pass the dictionary 'data' into a dataframe (convert a dictionary into a dataframe)
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3380000
# 2  NYC     8400000

# %%
#all the API methos you can use on a data frame. 
#all ways to construct a dataframe
#For full list of ways to create DataFrames from various sources go to the documentation for pandas:
website = 'http://pandas.pydata.org/pandas-docs/dev/generated/pandas.DataFrame.html'
webbrowser.open(website)
# Out:
# True
